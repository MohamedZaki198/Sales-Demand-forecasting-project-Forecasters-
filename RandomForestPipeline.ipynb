# %%
pip install mlflow
# Out:
# Requirement already satisfied: mlflow in f:\anaconda\lib\site-packages (3.5.0)
# Requirement already satisfied: mlflow-skinny==3.5.0 in f:\anaconda\lib\site-packages (from mlflow) (3.5.0)
# Requirement already satisfied: mlflow-tracing==3.5.0 in f:\anaconda\lib\site-packages (from mlflow) (3.5.0)
# Requirement already satisfied: Flask-CORS<7 in f:\anaconda\lib\site-packages (from mlflow) (6.0.1)
# Requirement already satisfied: Flask<4 in f:\anaconda\lib\site-packages (from mlflow) (3.1.0)
# Requirement already satisfied: alembic!=1.10.0,<2 in f:\anaconda\lib\site-packages (from mlflow) (1.17.0)
# Requirement already satisfied: cryptography<47,>=43.0.0 in f:\anaconda\lib\site-packages (from mlflow) (44.0.1)
# Requirement already satisfied: docker<8,>=4.0.0 in f:\anaconda\lib\site-packages (from mlflow) (7.1.0)
# Requirement already satisfied: fastmcp<3,>=2.0.0 in f:\anaconda\lib\site-packages (from mlflow) (2.12.5)
# Requirement already satisfied: graphene<4 in f:\anaconda\lib\site-packages (from mlflow) (3.4.3)
# Requirement already satisfied: matplotlib<4 in f:\anaconda\lib\site-packages (from mlflow) (3.10.0)
# Requirement already satisfied: numpy<3 in f:\anaconda\lib\site-packages (from mlflow) (2.1.3)
# Requirement already satisfied: pandas<3 in f:\anaconda\lib\site-packages (from mlflow) (2.2.3)
# Requirement already satisfied: pyarrow<22,>=4.0.0 in f:\anaconda\lib\site-packages (from mlflow) (19.0.0)
# Requirement already satisfied: scikit-learn<2 in f:\anaconda\lib\site-packages (from mlflow) (1.6.1)
# Requirement already satisfied: scipy<2 in f:\anaconda\lib\site-packages (from mlflow) (1.15.3)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in f:\anaconda\lib\site-packages (from mlflow) (2.0.39)
# Requirement already satisfied: waitress<4 in f:\anaconda\lib\site-packages (from mlflow) (3.0.2)
# Requirement already satisfied: cachetools<7,>=5.0.0 in f:\anaconda\lib\site-packages (from mlflow-skinny==3.5.0->mlflow) (5.5.1)
# Requirement already satisfied: click<9,>=7.0 in f:\anaconda\lib\site-packages (from mlflow-skinny==3.5.0->mlflow) (8.1.8)
# Requirement already satisfied: cloudpickle<4 in f:\anaconda\lib\site-packages (from mlflow-skinny==3.5.0->mlflow) (3.0.0)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in f:\anaconda\lib\site-packages (from mlflow-skinny==3.5.0->mlflow) (0.69.0)
# Requirement already satisfied: fastapi<1 in f:\anaconda\lib\site-packages (from mlflow-skinny==3.5.0->mlflow) (0.119.1)
# Requirement already satisfied: gitpython<4,>=3.1.9 in f:\anaconda\lib\site-packages (from mlflow-skinny==3.5.0->mlflow) (3.1.43)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in f:\anaconda\lib\site-packages (from mlflow-skinny==3.5.0->mlflow) (8.5.0)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in f:\anaconda\lib\site-packages (from mlflow-skinny==3.5.0->mlflow) (1.38.0)
# Requirement already satisfied: opentelemetry-proto<3,>=1.9.0 in f:\anaconda\lib\site-packages (from mlflow-skinny==3.5.0->mlflow) (1.38.0)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in f:\anaconda\lib\site-packages (from mlflow-skinny==3.5.0->mlflow) (1.38.0)
# Requirement already satisfied: packaging<26 in f:\anaconda\lib\site-packages (from mlflow-skinny==3.5.0->mlflow) (24.2)
# Requirement already satisfied: protobuf<7,>=3.12.0 in f:\anaconda\lib\site-packages (from mlflow-skinny==3.5.0->mlflow) (5.29.3)
# Requirement already satisfied: pydantic<3,>=1.10.8 in f:\anaconda\lib\site-packages (from mlflow-skinny==3.5.0->mlflow) (2.12.3)
# Requirement already satisfied: python-dotenv<2,>=0.19.0 in f:\anaconda\lib\site-packages (from mlflow-skinny==3.5.0->mlflow) (1.1.0)
# Requirement already satisfied: pyyaml<7,>=5.1 in f:\anaconda\lib\site-packages (from mlflow-skinny==3.5.0->mlflow) (6.0.2)
# Requirement already satisfied: requests<3,>=2.17.3 in f:\anaconda\lib\site-packages (from mlflow-skinny==3.5.0->mlflow) (2.32.3)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in f:\anaconda\lib\site-packages (from mlflow-skinny==3.5.0->mlflow) (0.5.3)
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in f:\anaconda\lib\site-packages (from mlflow-skinny==3.5.0->mlflow) (4.15.0)
# Requirement already satisfied: uvicorn<1 in f:\anaconda\lib\site-packages (from mlflow-skinny==3.5.0->mlflow) (0.38.0)
# Requirement already satisfied: Mako in f:\anaconda\lib\site-packages (from alembic!=1.10.0,<2->mlflow) (1.3.10)
# Requirement already satisfied: colorama in f:\anaconda\lib\site-packages (from click<9,>=7.0->mlflow-skinny==3.5.0->mlflow) (0.4.6)
# Requirement already satisfied: cffi>=1.12 in f:\anaconda\lib\site-packages (from cryptography<47,>=43.0.0->mlflow) (1.17.1)
# Requirement already satisfied: google-auth~=2.0 in f:\anaconda\lib\site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==3.5.0->mlflow) (2.41.1)
# Requirement already satisfied: pywin32>=304 in f:\anaconda\lib\site-packages (from docker<8,>=4.0.0->mlflow) (311)
# Requirement already satisfied: urllib3>=1.26.0 in f:\anaconda\lib\site-packages (from docker<8,>=4.0.0->mlflow) (2.3.0)
# Requirement already satisfied: starlette<0.49.0,>=0.40.0 in f:\anaconda\lib\site-packages (from fastapi<1->mlflow-skinny==3.5.0->mlflow) (0.48.0)
# Requirement already satisfied: authlib>=1.5.2 in f:\anaconda\lib\site-packages (from fastmcp<3,>=2.0.0->mlflow) (1.6.5)
# Requirement already satisfied: cyclopts>=3.0.0 in f:\anaconda\lib\site-packages (from fastmcp<3,>=2.0.0->mlflow) (4.0.0)
# Requirement already satisfied: exceptiongroup>=1.2.2 in f:\anaconda\lib\site-packages (from fastmcp<3,>=2.0.0->mlflow) (1.3.0)
# Requirement already satisfied: httpx>=0.28.1 in f:\anaconda\lib\site-packages (from fastmcp<3,>=2.0.0->mlflow) (0.28.1)
# Requirement already satisfied: mcp<1.17.0,>=1.12.4 in f:\anaconda\lib\site-packages (from fastmcp<3,>=2.0.0->mlflow) (1.16.0)
# Requirement already satisfied: openapi-core>=0.19.5 in f:\anaconda\lib\site-packages (from fastmcp<3,>=2.0.0->mlflow) (0.19.5)
# Requirement already satisfied: openapi-pydantic>=0.5.1 in f:\anaconda\lib\site-packages (from fastmcp<3,>=2.0.0->mlflow) (0.5.1)
# Requirement already satisfied: pyperclip>=1.9.0 in f:\anaconda\lib\site-packages (from fastmcp<3,>=2.0.0->mlflow) (1.11.0)
# Requirement already satisfied: rich>=13.9.4 in f:\anaconda\lib\site-packages (from fastmcp<3,>=2.0.0->mlflow) (13.9.4)
# Requirement already satisfied: Werkzeug>=3.1 in f:\anaconda\lib\site-packages (from Flask<4->mlflow) (3.1.1)
# Requirement already satisfied: Jinja2>=3.1.2 in f:\anaconda\lib\site-packages (from Flask<4->mlflow) (3.1.6)
# Requirement already satisfied: itsdangerous>=2.2 in f:\anaconda\lib\site-packages (from Flask<4->mlflow) (2.2.0)
# Requirement already satisfied: blinker>=1.9 in f:\anaconda\lib\site-packages (from Flask<4->mlflow) (1.9.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in f:\anaconda\lib\site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==3.5.0->mlflow) (4.0.7)
# Requirement already satisfied: smmap<5,>=3.0.1 in f:\anaconda\lib\site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==3.5.0->mlflow) (4.0.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in f:\anaconda\lib\site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.5.0->mlflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in f:\anaconda\lib\site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.5.0->mlflow) (4.9.1)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in f:\anaconda\lib\site-packages (from graphene<4->mlflow) (3.2.6)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in f:\anaconda\lib\site-packages (from graphene<4->mlflow) (3.2.0)
# Requirement already satisfied: python-dateutil<3,>=2.7.0 in f:\anaconda\lib\site-packages (from graphene<4->mlflow) (2.9.0.post0)
# Requirement already satisfied: zipp>=3.20 in f:\anaconda\lib\site-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==3.5.0->mlflow) (3.21.0)
# Requirement already satisfied: contourpy>=1.0.1 in f:\anaconda\lib\site-packages (from matplotlib<4->mlflow) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in f:\anaconda\lib\site-packages (from matplotlib<4->mlflow) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in f:\anaconda\lib\site-packages (from matplotlib<4->mlflow) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in f:\anaconda\lib\site-packages (from matplotlib<4->mlflow) (1.4.8)
# Requirement already satisfied: pillow>=8 in f:\anaconda\lib\site-packages (from matplotlib<4->mlflow) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in f:\anaconda\lib\site-packages (from matplotlib<4->mlflow) (3.2.0)
# Requirement already satisfied: anyio>=4.5 in f:\anaconda\lib\site-packages (from mcp<1.17.0,>=1.12.4->fastmcp<3,>=2.0.0->mlflow) (4.7.0)
# Requirement already satisfied: httpx-sse>=0.4 in f:\anaconda\lib\site-packages (from mcp<1.17.0,>=1.12.4->fastmcp<3,>=2.0.0->mlflow) (0.4.3)
# Requirement already satisfied: jsonschema>=4.20.0 in f:\anaconda\lib\site-packages (from mcp<1.17.0,>=1.12.4->fastmcp<3,>=2.0.0->mlflow) (4.23.0)
# Requirement already satisfied: pydantic-settings>=2.5.2 in f:\anaconda\lib\site-packages (from mcp<1.17.0,>=1.12.4->fastmcp<3,>=2.0.0->mlflow) (2.6.1)
# Requirement already satisfied: python-multipart>=0.0.9 in f:\anaconda\lib\site-packages (from mcp<1.17.0,>=1.12.4->fastmcp<3,>=2.0.0->mlflow) (0.0.20)
# Requirement already satisfied: sse-starlette>=1.6.1 in f:\anaconda\lib\site-packages (from mcp<1.17.0,>=1.12.4->fastmcp<3,>=2.0.0->mlflow) (3.0.2)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.59b0 in f:\anaconda\lib\site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==3.5.0->mlflow) (0.59b0)
# Requirement already satisfied: pytz>=2020.1 in f:\anaconda\lib\site-packages (from pandas<3->mlflow) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in f:\anaconda\lib\site-packages (from pandas<3->mlflow) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in f:\anaconda\lib\site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==3.5.0->mlflow) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.4 in f:\anaconda\lib\site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==3.5.0->mlflow) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in f:\anaconda\lib\site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==3.5.0->mlflow) (0.4.2)
# Requirement already satisfied: six>=1.5 in f:\anaconda\lib\site-packages (from python-dateutil<3,>=2.7.0->graphene<4->mlflow) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in f:\anaconda\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.5.0->mlflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in f:\anaconda\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.5.0->mlflow) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in f:\anaconda\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.5.0->mlflow) (2025.4.26)
# Requirement already satisfied: pyasn1>=0.1.3 in f:\anaconda\lib\site-packages (from rsa<5,>=3.1.4->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.5.0->mlflow) (0.4.8)
# Requirement already satisfied: joblib>=1.2.0 in f:\anaconda\lib\site-packages (from scikit-learn<2->mlflow) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in f:\anaconda\lib\site-packages (from scikit-learn<2->mlflow) (3.5.0)
# Requirement already satisfied: greenlet!=0.4.17 in f:\anaconda\lib\site-packages (from sqlalchemy<3,>=1.4.0->mlflow) (3.1.1)
# Requirement already satisfied: sniffio>=1.1 in f:\anaconda\lib\site-packages (from anyio>=4.5->mcp<1.17.0,>=1.12.4->fastmcp<3,>=2.0.0->mlflow) (1.3.0)
# Requirement already satisfied: h11>=0.8 in f:\anaconda\lib\site-packages (from uvicorn<1->mlflow-skinny==3.5.0->mlflow) (0.16.0)
# Requirement already satisfied: pycparser in f:\anaconda\lib\site-packages (from cffi>=1.12->cryptography<47,>=43.0.0->mlflow) (2.21)
# Requirement already satisfied: attrs>=23.1.0 in f:\anaconda\lib\site-packages (from cyclopts>=3.0.0->fastmcp<3,>=2.0.0->mlflow) (24.3.0)
# Requirement already satisfied: docstring-parser<4.0,>=0.15 in f:\anaconda\lib\site-packages (from cyclopts>=3.0.0->fastmcp<3,>=2.0.0->mlflow) (0.17.0)
# Requirement already satisfied: rich-rst<2.0.0,>=1.3.1 in f:\anaconda\lib\site-packages (from cyclopts>=3.0.0->fastmcp<3,>=2.0.0->mlflow) (1.3.2)
# Requirement already satisfied: docutils in f:\anaconda\lib\site-packages (from rich-rst<2.0.0,>=1.3.1->cyclopts>=3.0.0->fastmcp<3,>=2.0.0->mlflow) (0.21.2)
# Requirement already satisfied: httpcore==1.* in f:\anaconda\lib\site-packages (from httpx>=0.28.1->fastmcp<3,>=2.0.0->mlflow) (1.0.9)
# Requirement already satisfied: MarkupSafe>=2.0 in f:\anaconda\lib\site-packages (from Jinja2>=3.1.2->Flask<4->mlflow) (3.0.2)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in f:\anaconda\lib\site-packages (from jsonschema>=4.20.0->mcp<1.17.0,>=1.12.4->fastmcp<3,>=2.0.0->mlflow) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in f:\anaconda\lib\site-packages (from jsonschema>=4.20.0->mcp<1.17.0,>=1.12.4->fastmcp<3,>=2.0.0->mlflow) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in f:\anaconda\lib\site-packages (from jsonschema>=4.20.0->mcp<1.17.0,>=1.12.4->fastmcp<3,>=2.0.0->mlflow) (0.22.3)
# Requirement already satisfied: isodate in f:\anaconda\lib\site-packages (from openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow) (0.7.2)
# Requirement already satisfied: jsonschema-path<0.4.0,>=0.3.1 in f:\anaconda\lib\site-packages (from openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow) (0.3.4)
# Requirement already satisfied: more-itertools in f:\anaconda\lib\site-packages (from openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow) (10.3.0)
# Requirement already satisfied: openapi-schema-validator<0.7.0,>=0.6.0 in f:\anaconda\lib\site-packages (from openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow) (0.6.3)
# Requirement already satisfied: openapi-spec-validator<0.8.0,>=0.7.1 in f:\anaconda\lib\site-packages (from openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow) (0.7.2)
# Requirement already satisfied: parse in f:\anaconda\lib\site-packages (from openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow) (1.20.2)
# Requirement already satisfied: pathable<0.5.0,>=0.4.1 in f:\anaconda\lib\site-packages (from jsonschema-path<0.4.0,>=0.3.1->openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow) (0.4.4)
# Requirement already satisfied: rfc3339-validator in f:\anaconda\lib\site-packages (from openapi-schema-validator<0.7.0,>=0.6.0->openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow) (0.1.4)
# Requirement already satisfied: lazy-object-proxy<2.0.0,>=1.7.1 in f:\anaconda\lib\site-packages (from openapi-spec-validator<0.8.0,>=0.7.1->openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow) (1.12.0)
# Requirement already satisfied: email-validator>=2.0.0 in f:\anaconda\lib\site-packages (from pydantic[email]>=2.11.7->fastmcp<3,>=2.0.0->mlflow) (2.3.0)
# Requirement already satisfied: dnspython>=2.0.0 in f:\anaconda\lib\site-packages (from email-validator>=2.0.0->pydantic[email]>=2.11.7->fastmcp<3,>=2.0.0->mlflow) (2.8.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in f:\anaconda\lib\site-packages (from rich>=13.9.4->fastmcp<3,>=2.0.0->mlflow) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in f:\anaconda\lib\site-packages (from rich>=13.9.4->fastmcp<3,>=2.0.0->mlflow) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in f:\anaconda\lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.9.4->fastmcp<3,>=2.0.0->mlflow) (0.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import mlflow
import mlflow.sklearn
import mlflow.sklearn

# %%
mlflow.set_tracking_uri("http://127.0.0.1:5000")

mlflow.set_experiment("RandomForest")
# Out:
# 2025/11/26 15:57:59 INFO mlflow.tracking.fluent: Experiment with name 'RandomForest' does not exist. Creating a new experiment.
# <Experiment: artifact_location='mlflow-artifacts:/649018504180659342', creation_time=1764165479494, experiment_id='649018504180659342', last_update_time=1764165479494, lifecycle_stage='active', name='RandomForest', tags={}>

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("F:/DEPI Graduation Project/FMCG_2022_2024.csv")

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
upper_cap = df['stock_available'].quantile(0.99)
df['stock_available_capped'] = np.where(df['stock_available'] > upper_cap, upper_cap, df['stock_available'])
lower_cap = df['delivered_qty'].quantile(0.01)  # 1st percentile
upper_cap = df['delivered_qty'].quantile(0.99)  # 99th percentile

df['delivered_qty_capped'] = df['delivered_qty'].clip(lower=lower_cap, upper=upper_cap)

# %%
df['units_sold_log'] = np.log1p(df['units_sold'])
# Out:
# F:\Anaconda\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: invalid value encountered in log1p
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
df['Total_price per transaction'] = df['price_unit'] * df['units_sold']
df['Total_price per transaction'] = df['Total_price per transaction'].astype(float)

# %%
df["sell_through_rate"] = (df["units_sold"] / df["stock_available"]) * 100

# %%
df['units_sold_lag_1'] = df['units_sold'].shift(1)
df['units_sold_lag_7'] = df['units_sold'].shift(7)
df['units_sold_lag_30'] = df['units_sold'].shift(30)
df['units_sold_log_lag_1'] = df['units_sold_log'].shift(1)
df['units_sold_log_lag_7'] = df['units_sold_log'].shift(7)
df['units_sold_log_lag_30'] = df['units_sold_log'].shift(30)
df = df.dropna().reset_index(drop=True)
df["units_sold_roll7"] = df.groupby("sku")["units_sold"].transform(lambda x: x.rolling(7, min_periods=1).mean())
df["units_sold_roll30"] = df.groupby("sku")["units_sold"].transform(lambda x: x.rolling(30, min_periods=1).mean())
df["units_sold_log_roll7"]  = df.groupby("sku")["units_sold_log"].transform(lambda x: x.rolling(7, min_periods=1).mean())
df["units_sold_log_roll30"] = df.groupby("sku")["units_sold_log"].transform(lambda x: x.rolling(30, min_periods=1).mean())
df["promo_lag1"] = df["promotion_flag"] * df["units_sold_lag_1"]
df["promo_lag7"] = df["promotion_flag"] * df["units_sold_lag_7"]
df["promo_price_interaction"] = df["promotion_flag"] * df["price_unit"]
df["promo_roll7"] = df["promotion_flag"] * df["units_sold_roll7"]
df["promo_roll30"] = df["promotion_flag"] * df["units_sold_roll30"]

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

# -----------------------------
# 1. DROP LEAKAGE COLUMNS
# -----------------------------
leak_columns = [
    "units_sold",
    "Total_price per transaction",
    "sell_through_rate"
]

df = df.drop(columns=leak_columns)

# %%
# -----------------------------
# 2. FEATURE LISTS
# -----------------------------
categorical_cols = ["sku", "brand", "segment", "category", "channel", "region", "pack_type"]

numeric_cols = [
    "price_unit", "promotion_flag", "delivery_days",
    "units_sold_lag_1", "units_sold_lag_7", "units_sold_lag_30",
    "units_sold_log_lag_1", "units_sold_log_lag_7", "units_sold_log_lag_30",
    "units_sold_roll7", "units_sold_roll30",
    "units_sold_log_roll7", "units_sold_log_roll30",
    "promo_lag1", "promo_lag7", "promo_price_interaction",
    "promo_roll7", "promo_roll30","delivered_qty",
    "stock_available",
    "delivered_qty_capped",
    "stock_available_capped"
]

# %%
# -----------------------------
# 3. DEFINE X AND y
# -----------------------------
X = df[categorical_cols + numeric_cols]
y = df["units_sold_log"]

# HANDLE MISSING VALUES
X = X.fillna(0)

# %%
# -----------------------------
# 4. TIME-BASED SPLIT (NO SHUFFLE)
# -----------------------------
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, shuffle=False
)

# %%
# -----------------------------
# 5. PREPROCESSOR
# -----------------------------
preprocessor = ColumnTransformer([
    ("cat", OneHotEncoder(handle_unknown='ignore'), categorical_cols),
    ("num", StandardScaler(), numeric_cols)
], remainder='drop')

# %%
# -----------------------------
# 6. PIPELINE
# -----------------------------
pipeline = Pipeline([
    ("preprocess", preprocessor),

    ("model", RandomForestRegressor(
        n_estimators=300,
        max_depth=13,
        min_samples_split=3,
        min_samples_leaf=3,
        random_state=42,
        n_jobs=-1
    ))
])

# %%
with mlflow.start_run(run_name="RandomForest_pipeline"):
    pipeline.fit(X_train, y_train)
    y_pred = pipeline.predict(X_test)
    y_test_real = np.exp(y_test)
    y_pred_real = np.exp(y_pred)
    
    mae = mean_absolute_error(y_test_real, y_pred_real)
    rmse = np.sqrt(mean_squared_error(y_test_real, y_pred_real))
    r2 = r2_score(y_test_real, y_pred_real)
    mlflow.log_metric("MAE", mae)
    mlflow.log_metric("RMSE", rmse)
    mlflow.log_metric("R2", r2)
    input_example = X_train.head(1)
    mlflow.sklearn.log_model(pipeline, name="RandomForest_pipeline")
# Out:
# 2025/11/26 16:00:16 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 🏃 View run RandomForest_pipeline at: http://127.0.0.1:5000/#/experiments/649018504180659342/runs/ce374cfc562f4850aa7d2760ee945176
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/649018504180659342

# %%
# -----------------------------
# 8. EVALUATE
# -----------------------------
y_pred = pipeline.predict(X_test)
y_test_real = np.exp(y_test)
y_pred_real = np.exp(y_pred)

mae = mean_absolute_error(y_test_real, y_pred_real)
rmse = np.sqrt(mean_squared_error(y_test_real, y_pred_real))
r2 = r2_score(y_test_real, y_pred_real)

print("FINAL Pipeline MAE:", mae)
print("FINAL Pipeline RMSE:", rmse)
print("FINAL Pipeline R2:", r2)
# Out:
# FINAL Pipeline MAE: 3.0371212431948895
# FINAL Pipeline RMSE: 4.170919626678901
# FINAL Pipeline R2: 0.8126223023830561
